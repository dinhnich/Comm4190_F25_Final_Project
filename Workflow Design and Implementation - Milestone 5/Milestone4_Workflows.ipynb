# %% [markdown]
# ```mermaid
# ---
# title: UniTradeGPT Big Picture Workflow
# ---
# flowchart LR
#     User(User enters UniTradeGPT) --> Router{Intent router - what does the user want?}
#
#     Router -->|Find or choose something| Discover(Discover and choose items or homes<br/>- search and filtering<br/>- recommendations and comparison<br/>- interior design bundles<br/>- renting and subletting options)
#
#     Router -->|List or offer something| List(List or offer items or homes<br/>- sell or give away items<br/>- create trade listings<br/>- create rental or sublet listings)
#
#     Router -->|Logistics or help| Support(Logistics and support<br/>- scheduling pickup or delivery<br/>- contracts and agreements<br/>- general help and safety checks)
#
#     Discover --> Tx(Logistics and agreements engine<br/>- coordinate buyer and seller<br/>- propose time and place<br/>- draft contracts when needed)
#     List --> Tx
#     Support --> Tx
#
#     Tx --> Done(Finalize transaction<br/>- confirm with both parties<br/>- send notifications<br/>- update listing status)
